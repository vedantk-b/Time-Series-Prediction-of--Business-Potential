# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("trainset.csv", index_col="Region_Name")# dfr = dfr.T
dfr = df.T
dfr.rename(columns={"Region_Name":"Month"}, inplace=True)
dfr.insert(0, "Months", np.arange(1, 73))
dfr.reset_index(inplace=True)
dfr.drop(columns=["index"], inplace=True)
dfr
# Out:
# Region_Name  Months  Region 1  Region 2  Region 3  Region 4  Region 5  \
# 0                 1  0.154325  0.119708  0.178236  0.225016  0.318976
# 1                 2  0.122901  0.119831  0.165497  0.220602  0.316835
# 2                 3  0.127583  0.112970  0.190754  0.224240  0.328486
# 3                 4  0.501557  0.326049  0.321733  0.330916  0.483001
# 4                 5  0.103551  0.098852  0.203126  0.268934  0.380898
# ..              ...       ...       ...       ...       ...       ...
# 67               68  0.234171  0.218367  0.263643  0.228902  0.289498
# 68               69  0.294693  0.275179  0.296751  0.291502  0.368923
# 69               70  0.373754  0.344997  0.400269  0.364874  0.416527
# 70               71  0.333642  0.300503  0.360406  0.311379  0.372523
# 71               72  0.242176  0.215147  0.335923  0.271102  0.392835
#
# Region_Name  Region 6  Region 7  Region 8  Region 9  ...  Region 3906  \
# ...

# %%
for i in range(1000, 2000):#np.arange(1100, 1200):
    region = "Region " + str(i)
    if(dfr[region].max()-dfr[region].min()<10 and dfr[region].mean()>5 and dfr[region].mean()<10):
        dfr[region].plot(figsize=(20, 10), label = str(i))
        # plt.xlim(1, 74)
        print(i)
# Out:
# 1059
# 1176
# 1179
# 1240
# 1736
# 1746
# 1755
# 1764
# 1901
# 1906
# 1943
# 1968
# 1995

# %%
dfrcr = dfr.loc[:, "Region 1":"Region 3915"]
correlated = dfrcr.corr(method="pearson")

# %%
correlated
# Out:
# Region_Name  Region 1  Region 2  Region 3  Region 4  Region 5  Region 6  \
# Region_Name
# Region 1     1.000000  0.964116  0.913280  0.798888  0.558123  0.911741
# Region 2     0.964116  1.000000  0.947926  0.838048  0.602468  0.915952
# Region 3     0.913280  0.947926  1.000000  0.897151  0.690946  0.845841
# Region 4     0.798888  0.838048  0.897151  1.000000  0.830165  0.764907
# Region 5     0.558123  0.602468  0.690946  0.830165  1.000000  0.482620
# ...               ...       ...       ...       ...       ...       ...
# Region 3911  0.175763  0.168383  0.176442  0.007991 -0.007194  0.105935
# Region 3912  0.715788  0.693481  0.721161  0.544889  0.340526  0.675166
# Region 3913  0.645257  0.593155  0.634135  0.429847  0.195690  0.573927
# Region 3914  0.308479  0.315754  0.370111  0.238379  0.235396  0.187647
# Region 3915  0.713754  0.681085  0.692067  0.540367  0.289570  0.664912
#
# Region_Name  Region 7  Region 8  Region 9  Region 10  ...  Region 3906  \
# ...
