# %%
import pandas as pd

# %%
a = pd.read_csv("DeepSub_1.csv")
# a = a.drop(columns = {"Region 2181"})
b = pd.read_csv("DeepSubFin.csv")
b.rename(columns={"Months":"Month"}, inplace=True)
# c = pd.read_csv("2000 3000.csv")
# d = pd.read_csv("3000 3916.csv")
# m1 = a.merge(b)
# m1 = m1.merge(d)
# m1 = m1.drop(columns={"Unnamed: 0"})
# m1.to_csv("fndip.csv")
# m1.iloc[:, 3914:]
a.drop(columns="Unnamed: 0", inplace=True)
b.drop(columns={"Month"})
b["Month"] = ["Month "+str(i) for i in range(73, 88)]
a.drop(columns={"Month"})
a["Month"] = ["Month "+str(i) for i in range(73, 88)]
m1 = a.merge(b)
m1.set_index("Month", inplace=True)
m1.to_csv("fndip.csv")

# %%
m1
# Out:
#           Region 27  Region 61  Region 66  Region 69  Region 70  Region 73  \
# Month
# Month 73   0.841604   0.442715   0.900212   1.188957   3.064167   0.931942
# Month 74   0.748123   0.414154   1.324169   1.349752   3.174150   1.166524
# Month 75   1.104653   0.357071   1.422129   1.190100   2.575835   0.862147
# Month 76   0.875730   0.373323   1.721283   1.331121   3.107969   0.798268
# Month 77   0.759676   0.387037   1.531114   1.235504   5.171929   0.958989
# Month 78   0.734583   0.411955   1.300921   1.206384   5.872933   0.791798
# Month 79   0.806676   0.403373   1.824157   1.279050   8.864856   0.986513
# Month 80   0.743558   0.157875   1.551702   1.204721   5.472076   0.674850
# Month 81   0.635705   0.536620   1.447348   1.171811   6.760660   0.821233
# Month 82   0.027891   0.404522   0.900067   1.092438   4.764162   0.549931
# Month 83   0.505118   0.318003   1.182401   1.047282   6.621341   0.623284
# Month 84   0.668342   0.442034   1.511112   1.073001   5.278004   0.790134
# Month 85   0.799770   0.574259   1.435599   1.471580   3.823020   0.862892
# Month 86   0.919473   0.580309   1.649975   1.377524   4.403552   0.982435
# Month 87   1.129252   0.514823   1.376325   1.249430   4.261153   0.849303
#
#           Region 75  Region 76  Region 83  Region 85  ...  Region 3906  \
# Month                                                 ...
# Month 73   1.170943   1.146501   1.544171   0.992309  ...     0.797158
# Month 74   1.623960   1.461986   1.523997   1.041215  ...     0.922472
# Month 75   1.413895   1.315012   1.170082   0.920871  ...     0.646638
# Month 76   1.077592   1.131389   1.569680   0.936596  ...     0.671444
# Month 77   1.493368   1.357079   1.323886   0.902074  ...     0.652522
# Month 78   1.252167   1.213540   1.040309   0.843381  ...     0.946850
