# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("DeepSub (1).csv")

# %%
col = []
for idx, i in enumerate(df.columns):
    if(idx>1):
        nc = i[6:]
        ncn = int(nc)
        col.append(ncn)
col
dfr = df.drop(columns={"Unnamed: 0", "Month"})
dfr.loc[len(dfr.index)] = col
dfr
# Out:
#     Region 1  Region 2  Region 3  Region 6  Region 7  Region 8  Region 9  \
# 0   0.398122  0.372061  0.437532  0.325162  0.461044  0.365257  0.427673
# 1   0.362610  0.318767  0.401876  0.247051  0.438916  0.268621  0.359875
# 2   0.263766  0.221102  0.320588  0.171847  0.474312  0.186010  0.334173
# 3   0.275622  0.221851  0.310557  0.138315  0.382186  0.171576  0.268698
# 4   0.252173  0.191496  0.285627  0.119729  0.272101  0.160931  0.272504
# 5   0.336913  0.283412  0.331988  0.233760  0.381856  0.263773  0.305134
# 6   0.321828  0.302669  0.377643  0.256298  0.432404  0.258125  0.344371
# 7   0.321895  0.306597  0.384990  0.223945  0.383306  0.282610  0.305233
# 8   0.337018  0.327412  0.362927  0.333455  0.428894  0.303236  0.323273
# 9   0.121581  0.124563  0.230516  0.165025  0.250945  0.152184  0.211100
# 10  0.234171  0.218367  0.263643  0.182184  0.338011  0.174733  0.233715
# 11  0.294693  0.275179  0.296751  0.254764  0.312503  0.223991  0.325548
# ...

# %%
dfr = dfr.iloc[:, np.argsort(dfr.iloc[15])]

# %%
fin = dfr.drop(15)

# %%
fin["Month"] = ["Month "+str(i) for i in range(73, 88)]
fin.set_index("Month", inplace=True)

# %%
fin.to_csv("DeepSubFinM.csv")
fin
# Out:
#           Region 1  Region 2  Region 3  Region 4  Region 5  Region 6  \
# Month
# Month 73  0.398122  0.372061  0.437532  0.432136  0.482598  0.325162
# Month 74  0.362610  0.318767  0.401876  0.366376  0.408525  0.247051
# Month 75  0.263766  0.221102  0.320588  0.264211  0.381367  0.171847
# Month 76  0.275622  0.221851  0.310557  0.271887  0.336923  0.138315
# Month 77  0.252173  0.191496  0.285627  0.248869  0.288830  0.119729
# Month 78  0.336913  0.283412  0.331988  0.315252  0.366314  0.233760
# Month 79  0.321828  0.302669  0.377643  0.329762  0.392924  0.256298
# Month 80  0.321895  0.306597  0.384990  0.352229  0.370159  0.223945
# Month 81  0.337018  0.327412  0.362927  0.368514  0.422587  0.333455
# Month 82  0.121581  0.124563  0.230516  0.192878  0.282631  0.165025
# Month 83  0.234171  0.218367  0.263643  0.228902  0.289498  0.182184
# Month 84  0.294693  0.275179  0.296751  0.291502  0.368923  0.254764
# ...
